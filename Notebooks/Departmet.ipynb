# %% [markdown]
# standardize the wards name

# %%
import pandas as pd
import os

# %%
pm_dpt = pd.read_csv(r"../Cleaned amr data\LocationType_Clean.csv")

# %%
#inspect the data
pm_dpt['Department'].value_counts(dropna=False)
# Out:
# Department
# med     1718
# ped      716
# out      565
# mix      515
# sur      432
# obg      343
# eme      255
# neo      215
# MED      180
# nicu     156
# hao      126
# icu      122
# cli      113
# oth       86
# uro       64
# anc       30
# uc        18
# OTH       16
# int       11
# PED       10
# EME        9
# psy        7
# burn       4
# OBG        3
# mal        3
# gs         2
# ot         2
# HAO        2
# SUR        2
# NaN        1
# CLI        1
# card       1
# meta       1
# Name: count, dtype: int64

# %%
#shape cases
pm_dpt['Department'] = (
    pm_dpt ['Department']
    .str.strip()
    .str.lower()
)

# %%
#verify the changes
pm_dpt['Department'].value_counts(dropna=False)
# Out:
# Department
# med     1898
# ped      726
# out      565
# mix      515
# sur      434
# obg      346
# eme      264
# neo      215
# nicu     156
# hao      128
# icu      122
# cli      114
# oth      102
# uro       64
# anc       30
# uc        18
# int       11
# psy        7
# burn       4
# mal        3
# gs         2
# ot         2
# NaN        1
# card       1
# meta       1
# Name: count, dtype: int64

# %%
#save the cleaned data
#pm_dpt.to_csv(r"../Cleaned amr data\Department_w_nan.csv", index=False)
