# %% [markdown]
# Age - Clean blank datas [13] and standardize the variables in here if is x Days/ x Months / x Years, age category = New Born, Pediatric, Adults. [to do reaserch on this age division]
# and to search litreture view on the weight of this age input in this model and also to see how to categories these agaes according to WHO standard, and also compare with reality to our location and askdiscuss with mentors from this project
#
# Sex clean no blank when age are done cleaned, but got to standardize them, but actually are alreadyy in f and m
#
# location type inpatient_outpatient will be clean
#
# ward_departmnet - standardize the naming of variables.
