# %%
import pandas as pd

sp_date = pd.read_csv("specimen_information_clean_3.csv")

# %%
#inspect
sp_date['Specimen date'].sample(10, random_state=42)
# Out:
# 1614    18/12/2024 12:00:00 AM
# 4121           2024-10-10 0:00
# 2677            2024-8-10 0:00
# 4213             2024-5-3 0:00
# 3194     28/7/2024 12:00:00 AM
# 561             2024-9-10 0:00
# 3765            2024-10-8 0:00
# 2187     22/3/2024 12:00:00 AM
# 1485    18/11/2024 12:00:00 AM
# 177             2024-5-12 0:00
# Name: Specimen date, dtype: str

# %%
#crate masks
slash_mask = sp_date['Specimen date'].str.contains('/', na=False)

dash_mask = sp_date['Specimen date'].str.contains('-', na=False)

# %%
#check
print("Slash format:", slash_mask.sum())
print("Dash format :", dash_mask.sum())
# Out:
# Slash format: 3368
# Dash format : 2361

# %%
#convert with /
sp_date.loc[slash_mask, 'Specimen date'] = pd.to_datetime(
    sp_date.loc[slash_mask, 'Specimen date'],
    dayfirst=True
)
# Out:
# C:\Users\39dmi\AppData\Local\Temp\ipykernel_19232\2540244582.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp_date.loc[slash_mask, 'Specimen date'] = pd.to_datetime(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 #convert with /
# ----> 2 sp_date.loc[slash_mask, 'Specimen date'] = pd.to_datetime(
#       3     sp_date.loc[slash_mask, 'Specimen date'],
#       4     dayfirst=True
#       5 )
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:938, in _LocationIndexer.__setitem__(self, key, value)
#     933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
# --> 938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1953, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1950 # align and set the values
#    1951 if take_split_path:
#    1952     # We have to operate column-wise
# -> 1953     self._setitem_with_indexer_split_path(indexer, value, name)
#    1954 else:
#    1955     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:1997, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1993     self._setitem_with_indexer_2d_value(indexer, value)
#    1995 elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#    1996     # We are setting multiple rows in a single column.
# -> 1997     self._setitem_single_column(ilocs[0], value, pi)
#    1999 elif len(ilocs) == 1 and 0 != lplane_indexer != len(value):
#    2000     # We are trying to set N values into M entries of a single
#    2001     #  column, which is invalid for N != M
#    2002     # Exclude zero-len for e.g. boolean masking that is all-false
#    2004     if len(value) == 1 and not is_integer(info_axis):
#    2005         # This is a case like df.iloc[:3, [1]] = [0]
#    2006         #  where we treat as df.iloc[:3, 1] = 0
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexing.py:2181, in _iLocIndexer._setitem_single_column(self, loc, value, plane_indexer)
#    2171 if dtype == np.void:
#    2172     # This means we're expanding, with multiple columns, e.g.
#    2173     #     df = pd.DataFrame({'A': [1,2,3], 'B': [4,5,6]})
#    (...)   2176     # Here, we replace those temporary `np.void` columns with
#    2177     # columns of the appropriate dtype, based on `value`.
#    2178     self.obj.iloc[:, loc] = construct_1d_array_from_inferred_fill_value(
#    2179         value, len(self.obj)
#    2180     )
# -> 2181 self.obj._mgr.column_setitem(loc, plane_indexer, value)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:1520, in BlockManager.column_setitem(self, loc, idx, value, inplace_only)
#    1518     col_mgr.setitem_inplace(idx, value)
#    1519 else:
# -> 1520     new_mgr = col_mgr.setitem((idx,), value)
#    1521     self.iset(loc, new_mgr._block.values, inplace=True)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:604, in BaseBlockManager.setitem(self, indexer, value)
#     600     # No need to split if we either set all columns or on a single block
#     601     # manager
#     602     self = self.copy(deep=True)
# --> 604 return self.apply("setitem", indexer=indexer, value=value)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\internals\blocks.py:1667, in EABackedBlock.setitem(self, indexer, value)
#    1664 check_setitem_lengths(indexer, value, values)
#    1666 try:
# -> 1667     values[indexer] = value
#    1668 except (ValueError, TypeError):
#    1669     if isinstance(self.dtype, IntervalDtype):
#    1670         # see TestSetitemFloatIntervalWithIntIntervalValues
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\string_.py:863, in StringArray.__setitem__(self, key, value)
#     860 if self._readonly:
#     861     raise ValueError("Cannot modify read-only array")
# --> 863 value = self._maybe_convert_setitem_value(value)
#     865 key = check_array_indexer(self, key)
#     866 scalar_key = lib.is_scalar(key)
#
# File c:\Users\39dmi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arrays\string_.py:853, in StringArray._maybe_convert_setitem_value(self, value)
#     851         value = np.asarray(value)
#     852     if len(value) and not lib.is_string_array(value, skipna=True):
# --> 853         raise TypeError(
#     854             "Invalid value for dtype 'str'. Value should be a "
#     855             "string or missing value (or array of those)."
#     856         )
#     857 return value
#
# TypeError: Invalid value for dtype 'str'. Value should be a string or missing value (or array of those).

# %%
sp_date['Specimen date'] = sp_date['Specimen date'].str.strip()

# %%
sp_date['Specimen date'] = pd.to_datetime(
    sp_date['Specimen date'],
    format='mixed',
    dayfirst=True
)

# %%
sp_date['Specimen date'].head(10)
# Out:
# 0   2024-04-05
# 1   2024-06-02
# 2   2024-10-31
# 3   2024-08-18
# 4   2024-10-14
# 5   2024-10-24
# 6   2024-01-04
# 7   2024-01-03
# 8   2024-01-16
# 9   2024-01-18
# Name: Specimen date, dtype: datetime64[us]

# %%
sp_date.loc[
    sp_date['Specimen date'].dt.month == 2,
    'Specimen date'
].head(20)
# Out:
# 10    2024-02-03
# 11    2024-02-11
# 12    2024-02-11
# 13    2024-02-08
# 27    2024-02-23
# 41    2024-02-18
# 57    2024-02-16
# 67    2024-02-11
# 88    2024-02-19
# 94    2024-02-18
# 97    2024-02-06
# 98    2024-02-22
# 99    2024-02-22
# 107   2024-02-26
# 111   2024-02-26
# 182   2024-02-16
# 186   2024-02-18
# 197   2024-02-28
# 210   2024-02-05
# 213   2024-02-10
# Name: Specimen date, dtype: datetime64[us]

# %%
sp_date.loc[
    sp_date['Specimen date'].dt.month == 4,
    'Specimen date'
].head(20)
# Out:
# 0     2024-04-05
# 16    2024-04-25
# 48    2024-04-09
# 58    2024-04-08
# 71    2024-04-23
# 102   2024-04-18
# 105   2024-04-16
# 108   2024-04-30
# 117   2024-04-02
# 119   2024-04-15
# 120   2024-04-15
# 121   2024-04-18
# 122   2024-04-17
# 135   2024-04-25
# 158   2024-04-01
# 166   2024-04-28
# 175   2024-04-06
# 208   2024-04-22
# 222   2024-04-12
# 224   2024-04-06
# Name: Specimen date, dtype: datetime64[us]

# %%
sp_date["Specimen date"] = (
    sp_date["Specimen date"]
        .dt.strftime("%d/%m/%Y")
)

# %%
sp_date["Specimen date"].head(20)
# Out:
# 0     05/04/2024
# 1     02/06/2024
# 2     31/10/2024
# 3     18/08/2024
# 4     14/10/2024
# 5     24/10/2024
# 6     04/01/2024
# 7     03/01/2024
# 8     16/01/2024
# 9     18/01/2024
# 10    03/02/2024
# 11    11/02/2024
# 12    11/02/2024
# 13    08/02/2024
# 14    15/03/2024
# 15    23/03/2024
# 16    25/04/2024
# 17    23/05/2024
# 18    18/07/2024
# 19    27/07/2024
# Name: Specimen date, dtype: str

# %%
#sp_date.to_csv("specimen_information_clean_5.csv", index=False)

# %%
check = pd.read_csv("specimen_information_clean_5.csv")
check["Specimen date"].head()
# Out:
# 0    05/04/2024
# 1    02/06/2024
# 2    31/10/2024
# 3    18/08/2024
# 4    14/10/2024
# Name: Specimen date, dtype: str

# %%
sp_date['Specimen date'].isna().sum()
# Out:
# np.int64(2)

# %% [markdown]
# Want to drop the 2 NaN  found in the Specimen Date

# %%
sp_date = sp_date.dropna(subset=['Specimen date'])

# %%
sp_date['Specimen date'].isna().sum()
# Out:
# np.int64(0)

# %%
sp_date.to_csv("specimen_information_clean_6.csv", index=False)

# %%
check = pd.read_csv("specimen_information_clean_6.csv")
check["Specimen date"].head()
# Out:
# 0    05/04/2024
# 1    02/06/2024
# 2    31/10/2024
# 3    18/08/2024
# 4    14/10/2024
# Name: Specimen date, dtype: str

# %%
sp_date['Specimen date'].sample(10, random_state=42)
# Out:
# 3563    12/03/2024
# 4121    10/10/2024
# 4484    22/11/2024
# 4213    05/03/2024
# 5606    08/05/2024
# 561     09/10/2024
# 4178    12/01/2024
# 4218    23/01/2024
# 5599    09/04/2024
# 177     05/12/2024
# Name: Specimen date, dtype: str
